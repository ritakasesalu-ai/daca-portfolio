# %%
import pandas as pd
 
data = {
    'Toode': ['Teksad', 'Kleit', 'Jakk'],
    'Hind': [49.99, 89.50, 199.00],
    'Kogus': [2, 1, 1]
}
 
df = pd.DataFrame(data)
df


import pandas as pd

# Loo UrbanStyle näidisandmed (kui CSV puudub)
data = {
    'customer_id': [1001, 1002, 1003, 1001, 1002, 1004, 1003, 1001, 1005, 1004,
                    1002, 1003, 1005, 1001, 1006, 1004, 1002, 1007, 1003, 1005],
    'sale_date': ['2024-01-15', '2024-01-16', '2024-02-01', '2024-02-20', '2024-03-01',
                   '2024-03-05', '2024-03-15', '2024-04-10', '2024-04-12', '2024-04-20',
                   '2024-05-01', '2024-05-10', '2024-05-15', '2024-06-01', '2024-06-05',
                   '2024-06-10', '2024-06-20', '2024-07-01', '2024-07-05', '2024-07-10'],
    'total_price': [89.99, 45.50, 120.00, 67.30, 55.00, 210.00, 33.50, 145.00, 78.00, 92.00,
                     160.00, 44.00, 88.50, 230.00, 37.00, 175.00, 110.00, 65.00, 95.00, 125.00],
    'store_location': ['Tallinn', 'Tartu', 'Tallinn', 'Tallinn', 'Tartu', 'Pärnu', 'Tallinn', 'Tallinn',
             'Tartu', 'Pärnu', 'Tartu', 'Tallinn', 'Tartu', 'Tallinn', 'Pärnu', 'Pärnu',
             'Tartu', 'Tallinn', 'Tallinn', 'Tartu'],
    'product_category': ['Dresses', 'Tops', 'Denim', 'Accessories', 'Tops', 'Denim', 'Tops',
                         'Dresses', 'Denim', 'Accessories', 'Dresses', 'Tops', 'Denim',
                         'Dresses', 'Accessories', 'Denim', 'Tops', 'Accessories', 'Dresses', 'Denim']
}

df = pd.DataFrame(data)

# Uuri andmeid
print("=== SHAPE ===")
print(df.shape)

print("\n=== HEAD ===")
print(df.head())

print("\n=== INFO ===")
print(df.info())

print("\n=== DESCRIBE ===")
print(df.describe())

print("\n=== DTYPES ===")
print(df.dtypes)


print("unikaalseid kliente:", df['customer_id'].nunique())

print ("Asukohad:", df['store_location'].unique())
print("Tellimuste asukoha järgi:\n", df['store_location'].value_counts())
print ("Kogukäive:", df['total_price'].sum())


# Lihtne filter
tallinna_tellimused = df[df['store_location'] == 'Tallinn']

# Mitu tingimust (AND = &, OR = |)
suured_tallinn = df[(df['total_price'] > 100) & (df['store_location'] == 'Tallinn')]

# NOT (tilde ~)
mitte_tallinn = df[~(df['store_location'] == 'Tallinn')]

# Uus veerg arvutusega
df['discount'] = df['total_price'] * 0.1

# Tingimuslik veerg (nagu SQL CASE WHEN)
df['segment'] = df['total_price'].apply(
    lambda x: 'Suur' if x > 100 else 'Väike'
)

# Kuupäeva teisendamine
df['sale_date'] = pd.to_datetime(df['sale_date'])
df['month'] = df['sale_date'].dt.month
df['year'] = df['sale_date'].dt.year


import pandas as pd

# Kasuta Osa 1 DataFrame'i (df) või laadi uuesti
# df = pd.read_csv('urbanstyle_sales.csv')

# 1. Filtreerimine (WHERE)
print("=== Tallinna tellimused ===")
tallinn = df[df['store_location'] == 'Tallinn']
print(f"Kokku: {len(tallinn)} tellimust, käive: {tallinn['total_price'].sum():.2f} EUR")

# 2. Grupeerimie (GROUP BY)
print("\n=== Käive linniti ===")
city_revenue = df.groupby('store_location')['total_price'].agg(['sum', 'mean', 'count'])
city_revenue.columns = ['kogukäive', 'keskmine', 'tellimusi']
print(city_revenue.sort_values('kogukäive', ascending=False))

# 3. Uue veeru loomine (CASE WHEN)
df['order_size'] = df['total_price'].apply(
    lambda x: 'Suur (100+)' if x >= 100 else 'Väike (<100)'
)
print("\n=== Tellimused suuruse järgi ===")
print(df['order_size'].value_counts())



# Sinu kood:
customer_summary = df.groupby('customer_id')['total_price'].agg(
    kogukulutus='sum',
    keskmine='mean',
    tellimusi='count'
).reset_index()

# Sorteeri
customer_summary = customer_summary.sort_values('kogukulutus', ascending=False)

# Lisa VIP staatus
customer_summary['vip_status'] = customer_summary['kogukulutus'].apply(
    lambda x: 'VIP' if x > 300 else 'Tavaline'
)

print(customer_summary)

# Kliendiandmed
customers = pd.DataFrame({
    'customer_id': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    'first_name': ['Jüri', 'Kati', 'Maris', 'Peeter', 'Liina', 'Andres', 'Tiina'],
    'email': ['juri@mail.ee', 'kati@mail.ee', 'maris@mail.ee', 'peeter@mail.ee',
              'liina@mail.ee', 'andres@mail.ee', 'tiina@mail.ee']
})

# Ühenda müügiandmetega
merged = pd.merge(df, customers, on='customer_id', how='left')

# Nüüd saad näidata kliendi NIME, mitte ainult ID-d
# Kirjuta kood, mis näitab TOP 5 klienti nime ja kogukulutuse järgi
# ...


import plotly.express as px
# Käive linniti
city_data = df.groupby('store_location')['total_price'].sum().reset_index()
fig = px.bar(
    city_data,
    x='store_location',
    y='total_price',
    title='UrbanStyle käive linnade kaupa',
    labels={'store_location': 'Asukoht', 'total_price': 'Käive (EUR)'}
)
fig.show()
# Out:
# === SHAPE ===
# (20, 5)
#
# === HEAD ===
#    customer_id   sale_date  total_price store_location product_category
# 0         1001  2024-01-15        89.99        Tallinn          Dresses
# 1         1002  2024-01-16        45.50          Tartu             Tops
# 2         1003  2024-02-01       120.00        Tallinn            Denim
# 3         1001  2024-02-20        67.30        Tallinn      Accessories
# 4         1002  2024-03-01        55.00          Tartu             Tops
#
# === INFO ===
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       20 non-null     int64
#  1   sale_date         20 non-null     str
#  2   total_price       20 non-null     float64
#  3   store_location    20 non-null     str
#  4   product_category  20 non-null     str
# dtypes: float64(1), int64(1), str(3)
# memory usage: 1.4 KB
# None
#
# ...

# %%
# Käive kuude kaupa
df['sale_date'] = pd.to_datetime(df['sale_date'])
monthly = df.groupby(df['sale_date'].dt.to_period('M'))['total_price'].sum().reset_index()
monthly['sale_date'] = monthly['sale_date'].astype(str)

fig = px.line(
    monthly,
    x='sale_date',
    y='total_price',
    title='UrbanStyle kuukäive trend',
    labels={'sale_date': 'Kuu', 'total_price': 'Käive (EUR)'},
    markers=True
)
fig.show()

# %%
# Kliendi ostukäitumine: tellimuste arv vs kogukulutus
fig = px.scatter(
    customer_summary,
    x='tellimusi',
    y='kogukulutus',
    color='vip_status',
    title='Kliendid: ostusagedus vs kogukulutus',
    labels={'tellimusi': 'Tellimuste arv', 'kogukulutus': 'Kogukulutus (EUR)'}
)
fig.show()

# %%
# Käive osakaal kategooriate kaupa
cat_data = df.groupby('product_category')['total_price'].sum().reset_index()
fig = px.pie(
    cat_data,
    values='total_price',
    names='product_category',
    title='Käive jaotus tootekategooriate kaupa'
)
fig.show()

# %%
# Värvide kohandamine
fig.update_layout(
    plot_bgcolor='white',
    font=dict(family='Calibri', size=14),
    title_font_size=18
)

# Telgede kohandamine
fig.update_xaxes(title_text='Linn', tickangle=45)
fig.update_yaxes(title_text='Käive (EUR)')

# Salvestamine HTML-ina
fig.write_html('urbanstyle_chart.html')

# Salvestamine pildina (vajab kaleido paketti)
# pip install kaleido
fig.write_image('urbanstyle_chart.png')

# %%
import sys
print(sys.executable)

import kaleido
print(kaleido.__version__)

import sys
# !{sys.executable} -m pip install kaleido
# Out:
# c:\Users\kasutaja\Documents\DACA-Python\venv\Scripts\python.exe
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 5
#       1 import sys
#       2 print(sys.executable)
#       3
#       4 import kaleido
# ----> 5 print(kaleido.__version__)
#       6
#       7 import sys
#       8 get_ipython().system('{sys.executable} -m pip install kaleido')
#
# AttributeError: module 'kaleido' has no attribute '__version__'

# %%
import sys
# !{sys.executable} -m pip install --upgrade kaleido

# %%
import kaleido
print("Kaleido töötab")
# Out:
# Kaleido töötab

# %%
# Värvide kohandamine
fig.update_layout(
    plot_bgcolor='white',
    font=dict(family='Calibri', size=14),
    title_font_size=18
)

# Telgede kohandamine
fig.update_xaxes(title_text='Linn', tickangle=45)
fig.update_yaxes(title_text='Käive (EUR)')

# Salvestamine HTML-ina
fig.write_html('urbanstyle_chart.html')

# Salvestamine pildina (vajab kaleido paketti)
# pip install kaleido
fig.write_image('urbanstyle_chart.png')

# %%
import sys
print(sys.executable)

# !{sys.executable} -m pip install --upgrade kaleido
# Out:
# c:\Users\kasutaja\Documents\DACA-Python\venv\Scripts\python.exe
# ...

# %%
# Värvide kohandamine
fig.update_layout(
    plot_bgcolor='white',
    font=dict(family='Calibri', size=14),
    title_font_size=18
)

# Telgede kohandamine
fig.update_xaxes(title_text='Linn', tickangle=45)
fig.update_yaxes(title_text='Käive (EUR)')

# Salvestamine HTML-ina
fig.write_html('urbanstyle_chart.html')

# Salvestamine pildina (vajab kaleido paketti)
# pip install kaleido
fig.write_image('urbanstyle_chart.png')

# %%
fig = px.bar(
    sales_by_month,
    x='month',
    y='sales',
    title='Müük kuude lõikes'
)


import pandas as pd
import plotly.express as px

df['sale_date'] = pd.to_datetime(df['sale_date'])

# Loo kuu veerg
df['month'] = df['sale_date'].dt.to_period('M').astype(str)

# Arvuta kuukäive
monthly_revenue = df.groupby('month')['total_price'].sum().reset_index()

fig = px.line(
    monthly_revenue,
    x='month',
    y='total_price',
    title='UrbanStyle: Kuukäive trend',
    labels={
        'month': 'Kuu',
        'total_price': 'Käive (€)'
    },
    markers=True
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 fig = px.bar(
# ----> 2     sales_by_month,
#       3     x='month',
#       4     y='sales',
#       5     title='Müük kuude lõikes'
#
# NameError: name 'sales_by_month' is not defined

# %%
import pandas as pd
import plotly.express as px

df['sale_date'] = pd.to_datetime(df['sale_date'])

# Loo kuu veerg
df['month'] = df['sale_date'].dt.to_period('M').astype(str)

# Arvuta kuukäive
monthly_revenue = df.groupby('month')['total_price'].sum().reset_index()

fig = px.line(
    monthly_revenue,
    x='month',
    y='total_price',
    title='UrbanStyle: Kuukäive trend',
    labels={
        'month': 'Kuu',
        'total_price': 'Käive (€)'
    },
    markers=True
)

fig.show()

# %%
import pandas as pd
import plotly.express as px

# Kasuta olemasolevat df-i või loo uuesti (vt Osa 1A)

# Käive kategooriate kaupa
cat_revenue = df.groupby('product_category')['total_price'].sum().reset_index()
cat_revenue = cat_revenue.sort_values('total_price', ascending=True)

fig = px.bar(
    cat_revenue,
    x='total_price',
    y='product_category',
    orientation='h',
    text='total_price',
    title='UrbanStyle: Käive tootekategooriate kaupa',
    labels={
        'total_price': 'Müügitulu (EUR)',
        'product_category': 'Tootekategooria'
    },
    color='product_category',
    color_discrete_sequence=px.colors.qualitative.Bold
)
fig.show()
fig.update_layout(showlegend=False)

# %%
customer_summary = df.groupby('customer_id')['total_price'].agg(
    kogukulutus='sum',
    keskmine='mean',
    tellimusi='count'
).reset_index()

customer_summary = customer_summary.sort_values('kogukulutus', ascending=False)

customer_summary['vip_status'] = customer_summary['kogukulutus'].apply(
    lambda x: 'VIP' if x > 500 else 'Mitte-VIP'
)

print(customer_summary)
vip_counts = customer_summary['vip_status'].value_counts().reset_index()
vip_counts.columns = ['vip_status', 'count']

fig = px.pie(
    vip_counts,
    names='vip_status',
    values='count',
    title='Klientide jaotus VIP-staatuse järgi'
)

fig.show()
# Out:
#    customer_id  kogukulutus    keskmine  tellimusi vip_status
# 0         1001       532.29  133.072500          4        VIP
# 3         1004       477.00  159.000000          3  Mitte-VIP
# 1         1002       370.50   92.625000          4  Mitte-VIP
# 2         1003       292.50   73.125000          4  Mitte-VIP
# 4         1005       291.50   97.166667          3  Mitte-VIP
# 6         1007        65.00   65.000000          1  Mitte-VIP
# 5         1006        37.00   37.000000          1  Mitte-VIP

# %%
from supabase import create_client

url = "https://llzinozmlmlispovzjww.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Imxsemlub3ptbG1saXNwb3Z6and3Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NzczNDA3NjEsImV4cCI6MjA5MjkxNjc2MX0.H15RugvZG1me4FdtJlZBQ6zPGdwBCSjyuvwdqRweNwg"

supabase = create_client(url, key)

response = supabase.table("customers").select("*").execute()

customers_df = pd.DataFrame(response.data)

print(customers_df.head())

response = supabase.table("customers").select("email").execute()

customers_df = pd.DataFrame(response.data)

print("Kliente kokku:", len(customers_df))
print("E-mail olemas:", customers_df["email"].notna().sum())
print("E-mail puudub:", customers_df["email"].isna().sum())

email_stats = pd.DataFrame({
    "Staatus": ["E-mail olemas", "E-mail puudub"],
    "Kliente": [
        customers_df["email"].notna().sum(),
        customers_df["email"].isna().sum()
    ]
})

fig = px.pie(
    email_stats,
    names="Staatus",
    values="Kliente",
    title="Klientide e-mailide olemasolu"
)

fig.update_traces(textinfo="percent+label")
fig.show()

fig = px.pie(
    email_stats,
    names='Staatus',
    values='Kliente',
    title='Klientide e-mailide olemasolu'
)

fig.update_traces(
    textinfo='value+label'
)

fig.show()
# Out:
#    customer_id first_name last_name                   email           phone  \
# 0         2001        Eha       Aas        eha.aas@telia.ee  +372 8713 1455
# 1         2002      Aivar      Kõiv  aivar.koiv@outlook.com  +372 8943 8684
# 2         2003      Maris    Rebane   maris.rebane@telia.ee  +372 5918 5726
# 3         2005      Raivo    Koppel  raivo.koppel@yahoo.com  +372 5298 4365
# 4         2006       Aili      Must                     NaN  +372 5444 0491
#
#        city registration_date loyalty_tier  birth_year
# 0   Tallinn        2024-02-27          NaN        1973
# 1  Haapsalu        2025-01-09       bronze        1988
# 2     Tartu        2021-02-03          NaN        1999
# 3   Tallinn        2023-05-22       bronze        2004
# 4     Pärnu        2022-01-04          NaN        1986
# Kliente kokku: 1000
# E-mail olemas: 870
# E-mail puudub: 130

# %%
import pandas as pd
import plotly.express as px

# Kasuta olemasolevat df-i või loo uuesti (vt Osa 1A)
# Veendu, et sale_date on datetime tüüpi
df['sale_date'] = pd.to_datetime(df['sale_date'])

# Viitekuupäev (viimase tellimuse järgmine päev)
today = pd.to_datetime('2024-08-01')
print("Andmestiku periood:", df['sale_date'].min(), "kuni", df['sale_date'].max())
print("Viitekuupäev:", today)

# Recency: päevi viimasest ostust
recency = df.groupby('customer_id')['sale_date'].max().reset_index()
recency.columns = ['customer_id', 'last_purchase']
recency['recency_days'] = (today - recency['last_purchase']).dt.days

# Frequency: ostude arv
frequency = df.groupby('customer_id').size().reset_index(name='frequency')

# Monetary: kogukulutus
monetary = df.groupby('customer_id')['total_price'].sum().reset_index()
monetary.columns = ['customer_id', 'monetary']

# Liida kokku
rfm = recency[['customer_id', 'recency_days']].merge(
    frequency, on='customer_id'
).merge(
    monetary, on='customer_id'
)

print(rfm)

# Lihtsustatud skooride määramine (täida lüngad!)
# Recency: väiksem = parem (hiljuti ostis), seega pööra ümber
rfm['R_score'] = pd.qcut(rfm['recency_days'], q=3, labels=[3, 2, 1]).astype(int)

# Frequency: suurem = parem
rfm['F_score'] = pd.qcut(
    rfm['frequency'].rank(method='first'), q=3, labels=[1, 2, 3]
).astype(int)

# Monetary: suurem = parem
rfm['M_score'] = pd.qcut(rfm['monetary'], q=3, labels=[1, 2, 3]).astype(int)

# Koguskoor
rfm['RFM_score'] = rfm['R_score'] + rfm['F_score'] + rfm['M_score']

# Segmenteerimine
def assign_segment(score):
    if score >= 8:
        return 'VIP Champions'
    elif score >= 6:
        return 'Loyal Customers'
    elif score >= 4:
        return 'Potential Loyalists'
    else:
        return 'At Risk'

rfm['segment'] = rfm['RFM_score'].apply(assign_segment)
print(rfm.sort_values('RFM_score', ascending=False))

# Graafik 1: Segmentide jaotus
segment_counts = rfm['segment'].value_counts().reset_index()
fig1 = px.bar(
    segment_counts,
    x='segment',
    y='count',
    title='UrbanStyle: Kliendisegmentide jaotus (RFM)',
    labels={'segment': 'Segment', 'count': 'Klientide arv'},
    color='segment'
)
fig1.show()

# Graafik 2: Hajuvusdiagramm — Recency vs Monetary
fig2 = px.scatter(
    rfm,
    x='recency_days',
    y='monetary',
    color='segment',
    size='frequency',
    hover_data=['customer_id'],
    title='UrbanStyle: Recency vs Monetary (RFM)',
    labels={
        'recency_days': 'Päevi viimasest ostust',
        'monetary': 'Kogukulutus (EUR)'
    }
)
fig2.show()
# Out:
# Andmestiku periood: 2024-01-15 00:00:00 kuni 2024-07-10 00:00:00
# Viitekuupäev: 2024-08-01 00:00:00
#    customer_id  recency_days  frequency  monetary
# 0         1001            61          4    532.29
# 1         1002            42          4    370.50
# 2         1003            27          4    292.50
# 3         1004            52          3    477.00
# 4         1005            22          3    291.50
# 5         1006            57          1     37.00
# 6         1007            31          1     65.00
#    customer_id  recency_days  frequency  monetary  R_score  F_score  M_score  \
# 2         1003            27          4    292.50        3        3        2
# 1         1002            42          4    370.50        2        3        2
# 0         1001            61          4    532.29        1        2        3
# 3         1004            52          3    477.00        2        1        3
# 4         1005            22          3    291.50        3        2        1
# ...
